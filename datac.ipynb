# %%
import pandas as pd
inventory=pd.read_csv("inventory.csv")

new_column_names = ['Product_Name', 'Year_Month', 'Warehouse_Inventory','Inventory_Cost_Per_Unit']
inventory.columns = new_column_names
inventory.shape
# Out:
# (4200, 4)

# %%
inventory.head()
# Out:
#                                     Product_Name  Year_Month  \
# 0               Perfect Fitness Perfect Rip Deck      201712
# 1           Nike Men's Dri-FIT Victory Golf Polo      201712
# 2               O'Brien Men's Neoprene Life Vest      201712
# 3              Nike Men's Free 5.0+ Running Shoe      201712
# 4  Under Armour Girls' Toddler Spine Surge Runni      201712
#
#    Warehouse_Inventory  Inventory_Cost_Per_Unit
# 0                    0                  0.69517
# 1                    2                  1.29291
# 2                    0                  0.56531
# 3                    1                  1.26321
# 4                    0                  1.47648

# %%
inventory['Product_Name'].value_counts()
# Out:
# Product_Name
# Perfect Fitness Perfect Rip Deck                 36
# Bag Boy Beverage Holder                          36
# Nike Women's Legend V-Neck T-Shirt               36
# Titleist Pro V1x High Numbers Golf Balls         36
# Glove It Women's Mod Oval Golf Glove             36
#                                                  ..
# Nike Kids' Grade School KD VI Basketball Shoe    35
# Smart watch                                      35
# Baby sweater                                     35
# Men's gala suit                                  35
# Bowflex SelectTech 1090 Dumbbells                35
# Name: count, Length: 118, dtype: int64

# %%
inventory[['Year_Month','Warehouse_Inventory','Inventory_Cost_Per_Unit']][inventory['Product_Name']=='Perfect Fitness Perfect Rip Deck']
# Out:
#       Year_Month  Warehouse_Inventory  Inventory_Cost_Per_Unit
# 0         201712                    0                  0.69517
# 118       201711                    7                  2.30448
# 236       201710                    2                  2.28291
# 354       201709                  536                  1.65666
# 472       201708                  158                  0.56871
# 590       201707                   37                  2.05885
# 708       201706                  288                  0.50204
# 826       201705                  730                  0.94306
# 944       201704                  621                  0.88657
# 1062      201703                   57                  0.39551
# 1180      201702                  679                  0.91894
# 1298      201701                  529                  0.52827
# 1416      201612                  674                  0.36383
# 1534      201611                  411                  1.59273
# ...

# %%
inventory['Year_Month'] = pd.to_datetime(inventory['Year_Month'], format='%Y%m')
inventory.head()
# Out:
#                                     Product_Name Year_Month  \
# 0               Perfect Fitness Perfect Rip Deck 2017-12-01
# 1           Nike Men's Dri-FIT Victory Golf Polo 2017-12-01
# 2               O'Brien Men's Neoprene Life Vest 2017-12-01
# 3              Nike Men's Free 5.0+ Running Shoe 2017-12-01
# 4  Under Armour Girls' Toddler Spine Surge Runni 2017-12-01
#
#    Warehouse_Inventory  Inventory_Cost_Per_Unit
# 0                    0                  0.69517
# 1                    2                  1.29291
# 2                    0                  0.56531
# 3                    1                  1.26321
# 4                    0                  1.47648
